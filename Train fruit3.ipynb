# %% [markdown]
# <a href="https://colab.research.google.com/github/Narissarach/Project_eye/blob/main/Train%20fruit3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import PIL
import time
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import pickle as p
import plotly
from tensorflow.keras.models import load_model
from tensorflow.keras.models import model_from_json
import plotly.graph_objs as go
from tensorflow import keras
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## เตรียมชุดของข้อมูล

# %%
import pathlib
data_dir = pathlib.Path('/content/drive/My Drive/0fruit')

# %%
batch_size = 15   # กำหนดขนาดของแต่ละการอ่านข้อมูล
img_height = 150  # ความสูงของรูปภาพแต่ละรูป
img_width = 150   # ความกว้างของรูปภาพแต่ละรูป

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print("จำนวนรูปภาพทั้งหมด = ",image_count)
# Out:
# จำนวนรูปภาพทั้งหมด =  45

# %% [markdown]
# ## Train

# %%
train = tf.keras.preprocessing.image_dataset_from_directory(data_dir,
validation_split=0.2, # s แบ่งข้อมูล เพื่อ training 80% และ validation 20%
subset="training",
seed=123,
image_size=(img_height, img_width),
batch_size=batch_size)
val = tf.keras.preprocessing.image_dataset_from_directory(
data_dir,
validation_split=0.2,
subset="validation",
seed=123,
image_size=(img_height, img_width),
batch_size=batch_size)
# Out:
# Found 45 files belonging to 3 classes.
# Using 36 files for training.
# Found 45 files belonging to 3 classes.
# Using 9 files for validation.

# %%
class_names = train.class_names
print(class_names)
# Out:
# ['apple', 'mangosteen', 'pineapple']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9,9)) #ขนาด
for images, labels in train.take(1):
  for i in range(9): #มี 9 รูป
    ax = plt.subplot(3, 3, i + 1) #แถวละ 3
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (15, 150, 150, 3)
# (15,)

# %% [markdown]
# ## Normalization

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
normalized_ds = train.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.03417491 1.0

# %% [markdown]
# ## Model

# %%
num_classes = 3
epochs=20   # จำนวนครั้งที่เราจะ Train

# %%
model = Sequential([
layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
layers.Conv2D(16, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Conv2D(32, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Conv2D(64, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Flatten(),
layers.Dense(128, activation='relu'),
layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)       0
#
#  conv2d (Conv2D)             (None, 150, 150, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 20736)             0
#
#  dense (Dense)               (None, 128)               2654336
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 2,678,307
# Trainable params: 2,678,307
# Non-trainable params: 0
# _________________________________________________________________

# %%
his = model.fit(
train,
validation_data=val,
epochs=epochs
)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 10s 3s/step - loss: 1.5741 - accuracy: 0.3611 - val_loss: 1.7717 - val_accuracy: 0.1111
# Epoch 2/20
# 3/3 [==============================] - 2s 384ms/step - loss: 1.2303 - accuracy: 0.3889 - val_loss: 1.0348 - val_accuracy: 0.4444
# Epoch 3/20
# 3/3 [==============================] - 2s 383ms/step - loss: 1.0814 - accuracy: 0.3056 - val_loss: 0.9726 - val_accuracy: 0.3333
# Epoch 4/20
# 3/3 [==============================] - 2s 389ms/step - loss: 0.9947 - accuracy: 0.5278 - val_loss: 1.0205 - val_accuracy: 0.4444
# Epoch 5/20
# 3/3 [==============================] - 2s 379ms/step - loss: 0.8678 - accuracy: 0.6111 - val_loss: 0.8062 - val_accuracy: 0.5556
# Epoch 6/20
# 3/3 [==============================] - 2s 484ms/step - loss: 0.6767 - accuracy: 0.6944 - val_loss: 0.6646 - val_accuracy: 0.5556
# Epoch 7/20
# 3/3 [==============================] - 4s 677ms/step - loss: 0.4917 - accuracy: 0.9167 - val_loss: 0.7447 - val_accuracy: 0.6667
# Epoch 8/20
# 3/3 [==============================] - 2s 388ms/step - loss: 0.4188 - accuracy: 0.8611 - val_loss: 0.4136 - val_accuracy: 0.8889
# Epoch 9/20
# 3/3 [==============================] - 2s 392ms/step - loss: 0.3633 - accuracy: 0.8333 - val_loss: 0.4000 - val_accuracy: 0.8889
# Epoch 10/20
# 3/3 [==============================] - 2s 387ms/step - loss: 0.3093 - accuracy: 0.8889 - val_loss: 0.4078 - val_accuracy: 0.8889
# Epoch 11/20
# 3/3 [==============================] - 2s 382ms/step - loss: 0.1762 - accuracy: 0.9444 - val_loss: 0.3048 - val_accuracy: 0.8889
# Epoch 12/20
# 3/3 [==============================] - 2s 399ms/step - loss: 0.2312 - accuracy: 0.8889 - val_loss: 0.3927 - val_accuracy: 0.6667
# Epoch 13/20
# 3/3 [==============================] - 2s 390ms/step - loss: 0.0776 - accuracy: 1.0000 - val_loss: 0.2835 - val_accuracy: 0.8889
# Epoch 14/20
# 3/3 [==============================] - 2s 383ms/step - loss: 0.0778 - accuracy: 0.9722 - val_loss: 0.2928 - val_accuracy: 0.8889
# Epoch 15/20
# 3/3 [==============================] - 2s 381ms/step - loss: 0.0676 - accuracy: 0.9722 - val_loss: 0.6001 - val_accuracy: 0.5556
# Epoch 16/20
# 3/3 [==============================] - 2s 385ms/step - loss: 0.0707 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.8889
# Epoch 17/20
# 3/3 [==============================] - 2s 390ms/step - loss: 0.0276 - accuracy: 1.0000 - val_loss: 0.2585 - val_accuracy: 0.8889
# Epoch 18/20
# 3/3 [==============================] - 2s 385ms/step - loss: 0.0289 - accuracy: 1.0000 - val_loss: 0.2346 - val_accuracy: 0.8889
# Epoch 19/20
# 3/3 [==============================] - 2s 381ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.8889
# Epoch 20/20
# 3/3 [==============================] - 2s 385ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.1953 - val_accuracy: 0.8889

# %% [markdown]
# ## Save Model

# %%
with open('history_model', 'wb') as file:
   p.dump(his.history, file)

filepath='model1.h5'
model.save(filepath)
filepath_model = 'model1.json'
filepath_weights = 'weights_model.h5'
model_json = model.to_json()
with open(filepath_model, "w") as json_file:
   json_file.write(model_json)

model.save_weights('weights_model.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## Load Model

# %%
with open('history_model', 'rb') as file:
   his = p.load(file)

h1 = go.Scatter(y=his['loss'],
mode="lines", line=dict(
width=2,
color='blue'),
name="loss"
)
h2 = go.Scatter(y=his['val_loss'],
mode="lines", line=dict(
width=2,
color='red'),
name="val_loss"
)

data = [h1,h2]
layout1 = go.Layout(title='Loss',
xaxis=dict(title='epochs'),
yaxis=dict(title=' '))
fig1 = go.Figure(data, layout=layout1)
plotly.offline.iplot(fig1, filename="testMNIST")
predict_model = load_model(filepath)
predict_model.summary()
with open(filepath_model, 'r') as f:
   loaded_model_json = f.read()
predict_model = model_from_json(loaded_model_json)
predict_model.load_weights(filepath_weights)
print("Loaded model from disk")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="20d6deb4-0ae9-4583-aa48-f6268539177e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20d6deb4-0ae9-4583-aa48-f6268539177e")) {                    Plotly.newPlot(                        "20d6deb4-0ae9-4583-aa48-f6268539177e",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":"loss","y":[1.574136734008789,1.230330228805542,1.0814241170883179,0.99472576379776,0.8677625060081482,0.6766999363899231,0.49170148372650146,0.4187547564506531,0.3633325397968292,0.3092897832393646,0.1762339323759079,0.23117844760417938,0.0776352733373642,0.07775494456291199,0.06755775958299637,0.07070747017860413,0.02761610597372055,0.028938157483935356,0.007651987951248884,0.006099590100347996],"type":"scatter"},{"line":{"color":"red","width":2},"mode":"lines","name":"val_loss","y":[1.7717393636703491,1.0348258018493652,0.972615659236908,1.0205016136169434,0.8062182664871216,0.6645843982696533,0.7446816563606262,0.4136006236076355,0.40003469586372375,0.40782853960990906,0.3047696352005005,0.392683207988739,0.2835206091403961,0.2927757501602173,0.600120484828949,0.20988398790359497,0.25854939222335815,0.2346058487892151,0.1991349756717682,0.19526375830173492],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444 ...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 150, 150, 3)       0
#
#  conv2d (Conv2D)             (None, 150, 150, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 75, 75, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 20736)             0
#
#  dense (Dense)               (None, 128)               2654336
#
#  dense_1 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 2,678,307
# Trainable params: 2,678,307
# Non-trainable params: 0
# _________________________________________________________________
# Loaded model from disk

# %% [markdown]
# ## Prediction

# %%
import requests
from IPython.display import Image
from io import BytesIO
test_path = ('/content/drive/My Drive/a1.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple",score[0],"mangosteen",score[1],"pineapple",score[2])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple"
elif score[1]==np.max(score) :
   fruit = "mangosteen"
elif score[2]==np.max(score) :
   fruit = "pineapple"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# apple tf.Tensor(0.9988084, shape=(), dtype=float32) mangosteen tf.Tensor(5.267025e-05, shape=(), dtype=float32) pineapple tf.Tensor(0.001139041, shape=(), dtype=float32)
# AI apple มีความมั่นใจ 99.88%.

# %%
test_path = ('/content/drive/My Drive/0/ap.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple",score[0],"mangosteen",score[1],"pineapple",score[2])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple"
elif score[1]==np.max(score) :
   fruit = "mangosteen"
elif score[2]==np.max(score) :
   fruit = "pineapple"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 29ms/step
# apple tf.Tensor(0.9999958, shape=(), dtype=float32) mangosteen tf.Tensor(4.6482523e-07, shape=(), dtype=float32) pineapple tf.Tensor(3.6724637e-06, shape=(), dtype=float32)
# AI apple มีความมั่นใจ 100.00%.

# %%
test_path = ('/content/drive/My Drive/0/ma.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple",score[0],"mangosteen",score[1],"pineapple",score[2])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple"
elif score[1]==np.max(score) :
   fruit = "mangosteen"
elif score[2]==np.max(score) :
   fruit = "pineapple"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 28ms/step
# apple tf.Tensor(0.0024527248, shape=(), dtype=float32) mangosteen tf.Tensor(0.99332434, shape=(), dtype=float32) pineapple tf.Tensor(0.0042230133, shape=(), dtype=float32)
# AI mangosteen มีความมั่นใจ 99.33%.

# %%
test_path = ('/content/drive/My Drive/0/pi.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple",score[0],"mangosteen",score[1],"pineapple",score[2])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple"
elif score[1]==np.max(score) :
   fruit = "mangosteen"
elif score[2]==np.max(score) :
   fruit = "pineapple"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# apple tf.Tensor(0.0028296364, shape=(), dtype=float32) mangosteen tf.Tensor(1.5228485e-07, shape=(), dtype=float32) pineapple tf.Tensor(0.99717027, shape=(), dtype=float32)
# AI pineapple มีความมั่นใจ 99.72%.

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred,labels=[0,1])
print("Confusion Matrix:")
print(cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-cfc23d5a68e9> in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cm=confusion_matrix(y_test,y_pred,labels=[0,1])
#       3 print("Confusion Matrix:")
#       4 print(cm)
#
# NameError: name 'y_test' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(cm,cmap="Reds",annot=True,
            cbar_kws={"orientation":"vertical","label":"color bar"},
            xticklabels=[0,1],yticklabels=[0,1])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f50a863833cd> in <module>
#       1 import seaborn as sns
#       2 import matplotlib.pyplot as plt
# ----> 3 sns.heatmap(cm,cmap="Reds",annot=True,
#       4             cbar_kws={"orientation":"vertical","label":"color bar"},
#       5             xticklabels=[0,1],yticklabels=[0,1])
#
# NameError: name 'cm' is not defined

# %%
# normalized
print("Normalized Confusion Matrix:")
cm_normalized=np.round(cm/np.sum(cm,axis=1).reshape(-1,1),2)
print(cm_normalized)
sns.heatmap(cm,cmap="Greens",annot=True,
            cbar_kws={"orientation":"vertical","label":"color bar"},
            xticklabels=[0,1],yticklabels=[0,1])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Normalized Confusion Matrix")
plt.show()
# Out:
# Normalized Confusion Matrix:
# [[1. 0.]
#  [0. 1.]]

# %%
# heatmap

sns.heatmap(cm,cmap="Greens",annot=True,
            cbar_kws={"orientation":"vertical","label":"color bar"},
            xticklabels=[0,1],yticklabels=[0,1])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
