# %% [markdown]
# <a href="https://colab.research.google.com/github/Narissarach/Project_eye/blob/main/model1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Model 1

# %% [markdown]
# *** การกำหนดขนาดจากเปเปอร์ (https://www.agi.nu.ac.th/nred/Document/is-PDF/2562/geo_2562_05_FullPaper.pdf) ***

# %%
import tensorflow as tf
import PIL
import time
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import pickle as p
import pathlib
import plotly
from tensorflow.keras.models import load_model
from tensorflow.keras.models import model_from_json
import plotly.graph_objs as go
from tensorflow import keras
from tensorflow.keras.models import Sequential

# %% [markdown]
# ## เตรียมชุดของข้อมูล

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่า Mounted at /content/drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
batch_size = 10   # กำหนดขนาดของแต่ละการอ่านข้อมูล
img_height = 256  # ความสูงของรูปภาพแต่ละรูป
img_width = 256   # ความกว้างของรูปภาพแต่ละรูป

# %% [markdown]
# ## Train

# %%
#Train
data_train = pathlib.Path('/content/drive/MyDrive/2022Project/for_code/train')
train = tf.keras.utils.image_dataset_from_directory(data_train,image_size=(img_height, img_width))
# Out:
# Found 1216 files belonging to 4 classes.

# %%
class_names = train.class_names
print(class_names)
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9, 9)) #ขนาด
for images, labels in train.take(1):
  for i in range(9): #มี 9 รูป
    ax = plt.subplot(3, 3, i + 1) #แถวละ 3
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 256, 256, 3)
# (32,)

# %% [markdown]
# ## Validation

# %%
#Validation
data_validation = pathlib.Path('/content/drive/MyDrive/2022Project/for_code/validation')
val = tf.keras.utils.image_dataset_from_directory(data_validation,image_size=(img_height, img_width))
# Out:
# Found 152 files belonging to 4 classes.

# %%
class_names = val.class_names
print(class_names)
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9, 9)) #ขนาด
for images, labels in val.take(1):
  for i in range(9): #มี 9 รูป
    ax = plt.subplot(3, 3, i + 1) #แถวละ 3
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in val:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 256, 256, 3)
# (32,)

# %% [markdown]
# ## Test

# %%
#Test
data_test = pathlib.Path('/content/drive/MyDrive/2022Project/for_code/test')
test = tf.keras.utils.image_dataset_from_directory(data_test,image_size=(img_height, img_width))
# Out:
# Found 152 files belonging to 4 classes.

# %%
class_names = test.class_names
print(class_names)
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9, 9)) #ขนาด
for images, labels in test.take(1):
  for i in range(9): #มี 9 รูป
    ax = plt.subplot(3, 3, i + 1) #แถวละ 3
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in test:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 256, 256, 3)
# (32,)

# %% [markdown]
# ## Normalization

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1. / 255)
normalized_ds = train.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# ## Training

# %% [markdown]
# ### Model

# %%
num_classes = 4
epochs=10   # จำนวนครั้งที่เราจะ Train

# %%
model = Sequential([
layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
layers.Conv2D(16, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Conv2D(32, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Conv2D(64, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Flatten(),
layers.Dense(128, activation='relu'),
layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_2 (Dense)             (None, 128)               8388736
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 8,412,836
# Trainable params: 8,412,836
# Non-trainable params: 0
# _________________________________________________________________

# %%
his = model.fit(
train,
validation_data=val,
epochs=epochs
)
# Out:
# Epoch 1/10
# 38/38 [==============================] - 91s 2s/step - loss: 1.3070 - accuracy: 0.4441 - val_loss: 1.6620 - val_accuracy: 0.3289
# Epoch 2/10
# 38/38 [==============================] - 86s 2s/step - loss: 0.6989 - accuracy: 0.7451 - val_loss: 2.4466 - val_accuracy: 0.2895
# Epoch 3/10
# 38/38 [==============================] - 88s 2s/step - loss: 0.3055 - accuracy: 0.8972 - val_loss: 2.6860 - val_accuracy: 0.3092
# Epoch 4/10
# 38/38 [==============================] - 86s 2s/step - loss: 0.1776 - accuracy: 0.9515 - val_loss: 3.5366 - val_accuracy: 0.2105
# Epoch 5/10
# 38/38 [==============================] - 90s 2s/step - loss: 0.0519 - accuracy: 0.9885 - val_loss: 4.2828 - val_accuracy: 0.2500
# Epoch 6/10
# 38/38 [==============================] - 91s 2s/step - loss: 0.0459 - accuracy: 0.9860 - val_loss: 3.9080 - val_accuracy: 0.3355
# Epoch 7/10
# 38/38 [==============================] - 87s 2s/step - loss: 0.0183 - accuracy: 0.9959 - val_loss: 5.0050 - val_accuracy: 0.3026
# Epoch 8/10
# 38/38 [==============================] - 89s 2s/step - loss: 0.0132 - accuracy: 0.9951 - val_loss: 5.5994 - val_accuracy: 0.3158
# Epoch 9/10
# 38/38 [==============================] - 87s 2s/step - loss: 0.0124 - accuracy: 0.9967 - val_loss: 6.6294 - val_accuracy: 0.2632
# Epoch 10/10
# 38/38 [==============================] - 89s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 6.5515 - val_accuracy: 0.2434

# %% [markdown]
# ### Save Model

# %%
with open('history_model', 'wb') as file:
   p.dump(his.history, file)

filepath='model1.h5'
model.save(filepath)
filepath_model = 'model1.json'
filepath_weights = 'weights_model.h5'
model_json = model.to_json()
with open(filepath_model, "w") as json_file:
   json_file.write(model_json)

model.save_weights('weights_model.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ### Load Model

# %%
with open('history_model', 'rb') as file:
   his = p.load(file)

h1 = go.Scatter(y=his['loss'],
mode="lines", line=dict(
width=2,
color='blue'),
name="loss"
)
h2 = go.Scatter(y=his['val_loss'],
mode="lines", line=dict(
width=2,
color='red'),
name="val_loss"
)

data = [h1,h2]
layout1 = go.Layout(title='Loss',
xaxis=dict(title='epochs'),
yaxis=dict(title=' '))
fig1 = go.Figure(data, layout=layout1)
plotly.offline.iplot(fig1, filename="testMNIST")
predict_model = load_model(filepath)
predict_model.summary()
with open(filepath_model, 'r') as f:
   loaded_model_json = f.read()
predict_model = model_from_json(loaded_model_json)
predict_model.load_weights(filepath_weights)
print("Loaded model from disk")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8bf69e31-7bf5-4abf-8308-e7603c513774" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bf69e31-7bf5-4abf-8308-e7603c513774")) {                    Plotly.newPlot(                        "8bf69e31-7bf5-4abf-8308-e7603c513774",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":"loss","y":[1.3069733381271362,0.6988582015037537,0.3054884076118469,0.17755275964736938,0.051915887743234634,0.04594964161515236,0.018305564299225807,0.013192782178521156,0.012402662076056004,0.0015850169584155083],"type":"scatter"},{"line":{"color":"red","width":2},"mode":"lines","name":"val_loss","y":[1.6619514226913452,2.4465878009796143,2.6859724521636963,3.536552906036377,4.282769680023193,3.9080047607421875,5.004982948303223,5.5993523597717285,6.629411220550537,6.551487445831299],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line" ...
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_5 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 256, 256, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 128, 128, 16)     0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 128, 128, 32)      4640
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_2 (Dense)             (None, 128)               8388736
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 8,412,836
# Trainable params: 8,412,836
# Non-trainable params: 0
# _________________________________________________________________
# Loaded model from disk

# %% [markdown]
# ### Prediction

# %%
import requests
from IPython.display import Image
from io import BytesIO

# %%
# CSC
test_path = ('/content/drive/MyDrive/2022Project/Project/Test/CSC/FQ8979 23-03-12 RE_000_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 106ms/step
# CSC tf.Tensor(0.1038811, shape=(), dtype=float32) Normal tf.Tensor(0.5232811, shape=(), dtype=float32) PCV tf.Tensor(0.36561316, shape=(), dtype=float32) VKH tf.Tensor(0.0072246296, shape=(), dtype=float32)
# AI Normal มีความมั่นใจ 52.33%.

# %%
# Normal
test_path = ('/content/drive/MyDrive/2022Project/Project/Test/Normal/CJ5901 24-01-19 RE_000_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 102ms/step
# CSC tf.Tensor(0.15117109, shape=(), dtype=float32) Normal tf.Tensor(0.84859735, shape=(), dtype=float32) PCV tf.Tensor(2.0991988e-06, shape=(), dtype=float32) VKH tf.Tensor(0.000229423, shape=(), dtype=float32)
# AI Normal มีความมั่นใจ 84.86%.

# %%
# PCV
test_path = ('/content/drive/MyDrive/2022Project/Project/Test/PCV/AV0940 20-02-15 RE_000000_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# CSC tf.Tensor(0.99990904, shape=(), dtype=float32) Normal tf.Tensor(6.7777305e-06, shape=(), dtype=float32) PCV tf.Tensor(9.708424e-07, shape=(), dtype=float32) VKH tf.Tensor(8.321012e-05, shape=(), dtype=float32)
# AI CSC มีความมั่นใจ 99.99%.

# %%
# VKH
test_path = ('/content/drive/MyDrive/2022Project/Project/Test/VKH/KH7322 18-12-20 LE_000000_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 52ms/step
# CSC tf.Tensor(0.47865674, shape=(), dtype=float32) Normal tf.Tensor(2.5681398e-05, shape=(), dtype=float32) PCV tf.Tensor(0.030148868, shape=(), dtype=float32) VKH tf.Tensor(0.49116874, shape=(), dtype=float32)
# AI VKH มีความมั่นใจ 49.12%.

# %% [markdown]
# ### Testing

# %%
y_test = []; y_pred = []
class_names = test.class_names
for images, labels in test:
  for i in range(len(list(labels))):
    img_array = keras.preprocessing.image.img_to_array(images[i])
    X_test = tf.expand_dims(img_array, 0)
    score = predict_model.predict(X_test)
    if score[0][0]==np.max(score):
      eye = "CSC"
    elif score[0][1]==np.max(score):
      eye = "Normal"
    elif score[0][2]==np.max(score):
      eye = "PCV"
    elif score[0][3]==np.max(score):
      eye = "VKH"
    y_pred.append(eye)
    y_test.append(class_names[labels[i]])
# Out:
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 42ms/step

# %%
print(y_test)
print(len(y_test))
print(y_pred)
print(len(y_pred))
# Out:
# ['Normal', 'PCV', 'CSC', 'PCV', 'Normal', 'Normal', 'CSC', 'Normal', 'CSC', 'PCV', 'VKH', 'Normal', 'PCV', 'PCV', 'CSC', 'VKH', 'Normal', 'Normal', 'VKH', 'CSC', 'PCV', 'CSC', 'Normal', 'Normal', 'PCV', 'VKH', 'CSC', 'PCV', 'Normal', 'VKH', 'PCV', 'VKH', 'CSC', 'PCV', 'Normal', 'PCV', 'Normal', 'PCV', 'CSC', 'CSC', 'VKH', 'Normal', 'VKH', 'CSC', 'VKH', 'Normal', 'Normal', 'VKH', 'CSC', 'PCV', 'PCV', 'VKH', 'PCV', 'VKH', 'PCV', 'PCV', 'CSC', 'CSC', 'PCV', 'CSC', 'VKH', 'VKH', 'CSC', 'PCV', 'PCV', 'CSC', 'PCV', 'Normal', 'CSC', 'VKH', 'VKH', 'CSC', 'CSC', 'PCV', 'CSC', 'VKH', 'VKH', 'PCV', 'Normal', 'CSC', 'Normal', 'VKH', 'VKH', 'Normal', 'VKH', 'Normal', 'VKH', 'CSC', 'VKH', 'PCV', 'Normal', 'PCV', 'Normal', 'VKH', 'CSC', 'Normal', 'VKH', 'VKH', 'CSC', 'PCV', 'Normal', 'PCV', 'Normal', 'VKH', 'Normal', 'VKH', 'Normal', 'Normal', 'Normal', 'PCV', 'CSC', 'CSC', 'Normal', 'VKH', 'CSC', 'CSC', 'VKH', 'CSC', 'PCV', 'PCV', 'VKH', 'VKH', 'Normal', 'Normal', 'VKH', 'Normal', 'CSC', 'CSC', 'PCV', 'Normal', 'PCV', 'Normal', 'Normal', 'VKH', 'PCV', 'PCV', 'Normal', 'Normal', 'VKH', 'PCV', 'CSC', 'CSC', 'CSC', 'PCV', 'VKH', 'VKH', 'CSC', 'PCV', 'CSC', 'VKH', 'CSC', 'PCV']
# 152
# ['VKH', 'PCV', 'CSC', 'Normal', 'VKH', 'Normal', 'VKH', 'VKH', 'CSC', 'PCV', 'PCV', 'Normal', 'PCV', 'PCV', 'VKH', 'PCV', 'Normal', 'Normal', 'PCV', 'VKH', 'CSC', 'CSC', 'Normal', 'Normal', 'PCV', 'VKH', 'CSC', 'PCV', 'VKH', 'VKH', 'Normal', 'CSC', 'VKH', 'PCV', 'Normal', 'Normal', 'Normal', 'CSC', 'VKH', 'CSC', 'VKH', 'Normal', 'Normal', 'CSC', 'PCV', 'Normal', 'VKH', 'VKH', 'VKH', 'PCV', 'PCV', 'VKH', 'CSC', 'PCV', 'PCV', 'PCV', 'CSC', 'PCV', 'PCV', 'CSC', 'PCV', 'PCV', 'PCV', 'CSC', 'CSC', 'VKH', 'CSC', 'Normal', 'CSC', 'VKH', 'VKH', 'CSC', 'PCV', 'PCV', 'CSC', 'PCV', 'PCV', 'PCV', 'Normal', 'CSC', 'Normal', 'PCV', 'VKH', 'VKH', 'VKH', 'Normal', 'VKH', 'VKH', 'VKH', 'CSC', 'Normal', 'CSC', 'Normal', 'PCV', 'CSC', 'Normal', 'VKH', 'PCV', 'CSC', 'CSC', 'Normal', 'CSC', 'Normal', 'PCV', 'Normal', 'PCV', 'Normal', 'Normal', 'Normal', 'PCV', 'VKH', 'CSC', 'VKH', 'CSC', 'CSC', 'VKH', 'VKH', 'CSC', 'PCV', 'PCV', 'CSC', 'PCV', 'VKH', 'VKH', 'PCV', 'Normal', 'PCV', 'VKH', 'PCV', 'Normal', 'PCV', 'Normal', 'Normal', 'PCV', 'PCV', 'CSC', 'Normal', 'Normal', 'PCV', 'PCV', 'PCV', 'PCV', 'CSC', 'PCV', 'VKH', 'VKH', 'CSC', 'CSC', 'PCV', 'VKH', 'VKH', 'PCV']
# 152

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[19,  0,  7, 12],
#        [ 0, 29,  0,  9],
#        [12,  3, 23,  0],
#        [ 3,  1, 18, 16]])

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
test.class_names
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %%
cm_df = pd.DataFrame(cm,
                     index = ['CSC', 'Normal', 'PCV', 'VKH'], 
                     columns = ['CSC', 'Normal', 'PCV', 'VKH'])

# %%
cm_df
# Out:
#         CSC  Normal  PCV  VKH
# CSC      19       0    7   12
# Normal    0      29    0    9
# PCV      12       3   23    0
# VKH       3       1   18   16

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %% [markdown]
# ### หาค่า Accuracy,Recall, Precision, F1-score

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 0.572368

# %%
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('Recall: %f' % recall)
# Out:
# Recall: 0.572368

# %%
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('Precision: %f' % precision)
# Out:
# Precision: 0.587303

# %%
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.576557

# %% [markdown]
# ## Learning curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn import datasets
from sklearn.model_selection import learning_curve
