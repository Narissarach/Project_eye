# %% [markdown]
# <a href="https://colab.research.google.com/github/Narissarach/Project_eye/blob/main/modelOCTtrans7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ModelOCT

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from opencv-python) (1.22.4)

# %%
import os,cv2
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import glob
import PIL
import plotly
import plotly.graph_objs as go
import pandas as pd
from numpy import array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.layers import (Dense, Conv2D, AveragePooling2D, Flatten, Dropout, BatchNormalization, MaxPool2D)
import time
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.utils import np_utils
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.models import model_from_json
from tensorflow.keras.models import Sequential
import requests
from IPython.display import Image
from io import BytesIO  
import pickle as p 
import plotly.graph_objs as go  
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras import backend as K
K.image_data_format()
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## เตรียมชุดของข้อมูล

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่า Mounted at /content/drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os # os จัดการเกี่ยวกับไฟล์ต่างๆ ในโฟล์เดอร์
path = '/content/drive/My Drive/Projecteye/model'  # data เราอยู่โฟล์เดอร์ไหน

# %%
batch_size = 16   # กำหนดขนาดของแต่ละการอ่านข้อมูล
img_height = 256  # ความสูงของรูปภาพแต่ละรูป
img_width = 256   # ความกว้างของรูปภาพแต่ละรูป

num_classes = 4

# %% [markdown]
# ## Train

# %%
# Train
train_dir = "/content/drive/My Drive/Projecteye/model/train"
train_datagen = ImageDataGenerator(rescale = 1./255)

train_set = train_datagen.flow_from_directory(train_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')
# Out:
# Found 502 images belonging to 4 classes.

# %%
print('Train')
ids, counts = np.unique(train_set.classes, return_counts=True)
print(ids)        # คลาส
print(counts)     # จำนวนภาพของคลาส
# Out:
# Train
# [0 1 2 3]
# [131 117 123 131]

# %%
train_set[0][0][0].shape   # W*H*3 (3 Channel RGB)
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Validation

# %%
# Validation
val_dir ="/content/drive/My Drive/Projecteye/model/validation"
val_datagen = ImageDataGenerator(rescale = 1./255)

val_set = val_datagen.flow_from_directory(val_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')
# Out:
# Found 63 images belonging to 4 classes.

# %%
print('Validation')
ids, counts = np.unique(val_set.classes, return_counts=True)
print(ids)        # คลาส
print(counts)     # จำนวนข้อมูลของคลาส
# Out:
# Validation
# [0 1 2 3]
# [16 15 15 17]

# %% [markdown]
# ## Test

# %%
# Test
test_dir ="/content/drive/My Drive/Projecteye/model/test"
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = tf.keras.utils.image_dataset_from_directory(test_dir,image_size=(img_height, img_width))
# Out:
# Found 63 files belonging to 4 classes.

# %%
class_names = test_set.class_names
print(class_names)
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %% [markdown]
# ## Setup และโหลด Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
target_img_shape = (256,256) 
train_dir = "/content/drive/My Drive/Projecteye/model/train" #train dir
val_dir = "/content/drive/My Drive/Projecteye/model/validation" #validation dir

# %%
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
train_set = train_datagen.flow_from_directory(train_dir,
                                              target_size = target_img_shape,
                                              batch_size = 8,
                                              class_mode = 'sparse')

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_set = val_datagen.flow_from_directory(val_dir,
                                              target_size = target_img_shape,
                                              batch_size = 8,
                                              class_mode = 'sparse')
# Out:
# Found 502 images belonging to 4 classes.
# Found 63 images belonging to 4 classes.

# %% [markdown]
# ## Visualize

# %%
print(train_set.class_indices)
for image_batch, labels_batch in train_set:
  print(image_batch.shape)
  print(labels_batch.shape)

  img = image_batch[0] - image_batch[0].min()
  img /= 255.0
  plt.imshow(img)
  print('class:', labels_batch[0])
  break
# Out:
# {'CSC': 0, 'Normal': 1, 'PCV': 2, 'VKH': 3}
# (8, 256, 256, 3)
# (8,)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# class: 2.0

# %%
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
labels

for i in ids:
  print('{:>8} = {}' . format(labels[i], counts[i]))
# Out:
#      CSC = 16
#   Normal = 15
#      PCV = 15
#      VKH = 17

# %%
ids, counts = np.unique(val_set.classes, return_counts=True)   #ของ Validation
print(ids)
print(counts)
# Out:
# [0 1 2 3]
# [16 15 15 17]

# %%
_, train_count = np.unique(train_set.classes, return_counts=True)
_, val_count = np.unique(val_set.classes, return_counts=True)

print('สัดส่วน Validation/Training set:', val_count/train_count*100)
# Out:
# สัดส่วน Validation/Training set: [12.21374046 12.82051282 12.19512195 12.97709924]

# %%
in_shape = (target_img_shape[0], target_img_shape[1],3)
in_shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## สร้างโมเดล CNN

# %%
base_model = ResNet50(include_top = False,
                      weights='imagenet',        # Load weight
                      input_shape=in_shape)
model = Sequential()

model.add(base_model) # ตัวฐาน (Pre-trained)
model.add(Flatten())
model.add(Dense(128, activation='relu')) 

model.add(Dense(256, activation='relu')) 

model.add(Dense(4, activation='softmax')) # 4 คลาส

model.summary() # ดูสรุป
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 128)               16777344
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 40,399,108
# Trainable params: 40,345,988
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
base_model.trainable = False # Freeze ส่วนที่เป็นฐาน (ResNet50)

# %%
print("Trainable..\n---")
for variable in model.trainable_variables:
  print(variable.name)
# Out:
# Trainable..
# ---
# dense/kernel:0
# dense/bias:0
# dense_1/kernel:0
# dense_1/bias:0
# dense_2/kernel:0
# dense_2/bias:0

# %% [markdown]
# ตรวจสอบด้วย .summary() อีกครั้งจะพบว่า Trainable ลดลงเท่ากับการ Freeze มีผลแล้ว

# %%
model.summary() # ดูสรุป
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 128)               16777344
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 40,399,108
# Trainable params: 16,811,396
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %% [markdown]
# ### Compile และ Train

# %%
from keras.api._v2.keras import callbacks
import time
model.compile(loss = 'sparse_categorical_crossentropy', 
              optimizer = 'adam', 
              metrics = ['accuracy'])

start = time.time()

history = model.fit(train_set,
                    validation_data=val_set, 
                    epochs=20,verbose=1)

end = time.time()
print("Time Taken: {:.2f} minutes".format((end-start)/60))
# Out:
# Epoch 1/20
# 63/63 [==============================] - 193s 3s/step - loss: 14.0550 - accuracy: 0.5159 - val_loss: 1.8088 - val_accuracy: 0.7460
# Epoch 2/20
# 63/63 [==============================] - 164s 3s/step - loss: 1.0213 - accuracy: 0.8566 - val_loss: 0.8316 - val_accuracy: 0.8571
# Epoch 3/20
# 63/63 [==============================] - 163s 3s/step - loss: 0.3080 - accuracy: 0.9283 - val_loss: 1.1478 - val_accuracy: 0.7778
# Epoch 4/20
# 63/63 [==============================] - 161s 3s/step - loss: 0.4066 - accuracy: 0.9422 - val_loss: 0.6029 - val_accuracy: 0.8413
# Epoch 5/20
# 63/63 [==============================] - 162s 3s/step - loss: 0.2330 - accuracy: 0.9622 - val_loss: 1.2225 - val_accuracy: 0.8095
# Epoch 6/20
# 63/63 [==============================] - 162s 3s/step - loss: 0.1199 - accuracy: 0.9701 - val_loss: 0.9895 - val_accuracy: 0.8413
# Epoch 7/20
# 63/63 [==============================] - 160s 3s/step - loss: 0.2405 - accuracy: 0.9582 - val_loss: 1.1037 - val_accuracy: 0.8730
# Epoch 8/20
# 63/63 [==============================] - 163s 3s/step - loss: 0.0773 - accuracy: 0.9761 - val_loss: 2.4509 - val_accuracy: 0.8254
# Epoch 9/20
# 63/63 [==============================] - 161s 3s/step - loss: 0.5673 - accuracy: 0.9163 - val_loss: 2.2605 - val_accuracy: 0.7619
# Epoch 10/20
# 63/63 [==============================] - 162s 3s/step - loss: 0.2856 - accuracy: 0.9602 - val_loss: 3.4696 - val_accuracy: 0.8095
# Epoch 11/20
# 63/63 [==============================] - 157s 2s/step - loss: 0.3796 - accuracy: 0.9641 - val_loss: 2.8551 - val_accuracy: 0.8095
# Epoch 12/20
# 63/63 [==============================] - 155s 2s/step - loss: 0.3897 - accuracy: 0.9562 - val_loss: 3.4268 - val_accuracy: 0.7778
# Epoch 13/20
# 63/63 [==============================] - 161s 3s/step - loss: 0.4704 - accuracy: 0.9641 - val_loss: 3.8114 - val_accuracy: 0.7302
# Epoch 14/20
# 63/63 [==============================] - 161s 3s/step - loss: 0.2177 - accuracy: 0.9781 - val_loss: 1.6563 - val_accuracy: 0.8571
# Epoch 15/20
# 63/63 [==============================] - 164s 3s/step - loss: 0.4985 - accuracy: 0.9582 - val_loss: 2.6511 - val_accuracy: 0.8571
# Epoch 16/20
# 63/63 [==============================] - 163s 3s/step - loss: 0.4000 - accuracy: 0.9701 - val_loss: 3.7860 - val_accuracy: 0.7937
# Epoch 17/20
# 63/63 [==============================] - 159s 3s/step - loss: 0.4829 - accuracy: 0.9402 - val_loss: 3.0649 - val_accuracy: 0.7619
# Epoch 18/20
# 63/63 [==============================] - 163s 3s/step - loss: 0.0872 - accuracy: 0.9841 - val_loss: 2.2170 - val_accuracy: 0.8095
# Epoch 19/20
# 63/63 [==============================] - 160s 3s/step - loss: 0.0606 - accuracy: 0.9841 - val_loss: 2.9144 - val_accuracy: 0.8095
# Epoch 20/20
# 63/63 [==============================] - 153s 2s/step - loss: 0.0516 - accuracy: 0.9880 - val_loss: 2.8965 - val_accuracy: 0.8254
# Time Taken: 60.96 minutes

# %% [markdown]
# ### Save Model

# %%
modelOCT = '/Model'
if not os.path.exists(path+modelOCT):
    os.makedirs(path+modelOCT)
os.makedirs('/content/drive/My Drive/Projecteye/savemodel/', exist_ok=True)
model.save('/content/drive/MyDrive/Projecteye/savemodel/modelOCTtrans7.h5')

with open('history_model', 'wb') as file:
   p.dump(history.history, file)

filepath='modelOCTtrans7.h5'
model.save(filepath)
filepath_model = 'modelOCTtrans7.json'
filepath_weights = 'weightsmodeltrans7.h5'
model_json = model.to_json()
with open(filepath_model, "w") as json_file:
   json_file.write(model_json)

model.save_weights('weightsmodeltrans7.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ### Load Model

# %%
with open('history_model', 'rb') as file:
   his = p.load(file)

h1 = go.Scatter(y=his['val_accuracy'],
mode="lines", line=dict(
width=2,
color='blue'),
name="val_accuracy"
)
h2 = go.Scatter(y=his['val_loss'],
mode="lines", line=dict(
width=2,
color='red'),
name="val_loss"
)

data = [h1,h2]
layout1 = go.Layout(title='Loss',
xaxis=dict(title='epochs'),
yaxis=dict(title=' '))
fig1 = go.Figure(data, layout=layout1)
plotly.offline.iplot(fig1, filename="testOCT")
predict_model = load_model(filepath)
predict_model.summary()
with open(filepath_model, 'r') as f:
   loaded_model_json = f.read()
predict_model = model_from_json(loaded_model_json)
predict_model.load_weights(filepath_weights)
print("Loaded model from disk")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="efbcf074-e2b6-4d5e-b8d5-9ab0679c30de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("efbcf074-e2b6-4d5e-b8d5-9ab0679c30de")) {                    Plotly.newPlot(                        "efbcf074-e2b6-4d5e-b8d5-9ab0679c30de",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":"val_accuracy","y":[0.7460317611694336,0.8571428656578064,0.7777777910232544,0.841269850730896,0.8095238208770752,0.841269850730896,0.8730158805847168,0.8253968358039856,0.761904776096344,0.8095238208770752,0.8095238208770752,0.7777777910232544,0.7301587462425232,0.8571428656578064,0.8571428656578064,0.7936508059501648,0.761904776096344,0.8095238208770752,0.8095238208770752,0.8253968358039856],"type":"scatter"},{"line":{"color":"red","width":2},"mode":"lines","name":"val_loss","y":[1.8088219165802002,0.8316064476966858,1.1477693319320679,0.6028655171394348,1.2225382328033447,0.9894570112228394,1.1037228107452393,2.4509146213531494,2.2604613304138184,3.469592571258545,2.8550777435302734,3.4268243312835693,3.8113763332366943,1.656285285949707,2.6510775089263916,3.7860238552093506,3.064884901046753,2.216977834701538,2.9143688678741455,2.896531343460083],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444444444 ...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 8, 8, 2048)        23587712
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 128)               16777344
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 40,399,108
# Trainable params: 16,811,396
# Non-trainable params: 23,587,712
# _________________________________________________________________
# Loaded model from disk

# %% [markdown]
# ## ประเมิน

# %%
plt.figure(figsize = (10, 3.5))
plt.subplot(1, 2 , 1)
plt.title('Loss')
plt.plot(history.history['loss'], label = 'Train Loss')
plt.plot(history.history['val_loss'], 'r', lw = 3.2, label = 'Validation loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label = 'Train')
plt.plot(history.history['val_accuracy'], 'r', lw = 3.2, label = 'Validation')
plt.legend()
plt.tight_layout()
plt.show()

# %%
acc = model.evaluate(val_set, steps = len(val_set), verbose = 0)
print('score = {:.3f}' .format(acc[1]))
# Out:
# score = 0.825

# %% [markdown]
# ### Prediction

# %%
import requests
from IPython.display import Image
from io import BytesIO
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.preprocessing import image 
import keras.utils as image
from keras.models import load_model

# %%
train_set.class_indices
# Out:
# {'CSC': 0, 'Normal': 1, 'PCV': 2, 'VKH': 3}

# %%
# CSC
test_path = ('/content/drive/My Drive/Projecteye/model/test/CSC/CD7445 22-07-16 LE_001_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 2s 2s/step
# CSC tf.Tensor(0.47536692, shape=(), dtype=float32) Normal tf.Tensor(0.17487772, shape=(), dtype=float32) PCV tf.Tensor(0.17487772, shape=(), dtype=float32) VKH tf.Tensor(0.17487772, shape=(), dtype=float32)
# AI CSC มีความมั่นใจ 47.54%.

# %%
# Normal
test_path = ('/content/drive/My Drive/Projecteye/model1/test/Normal/AA0598 17-11-22 RE_000_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 246ms/step
# CSC tf.Tensor(0.17487772, shape=(), dtype=float32) Normal tf.Tensor(0.47536692, shape=(), dtype=float32) PCV tf.Tensor(0.17487772, shape=(), dtype=float32) VKH tf.Tensor(0.17487772, shape=(), dtype=float32)
# AI Normal มีความมั่นใจ 47.54%.

# %%
# PCV
test_path = ('/content/drive/My Drive/Projecteye/model1/test/PCV/AF4715 18-10-17 LE_001_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 295ms/step
# CSC tf.Tensor(0.1748777, shape=(), dtype=float32) Normal tf.Tensor(0.1748777, shape=(), dtype=float32) PCV tf.Tensor(0.47536686, shape=(), dtype=float32) VKH tf.Tensor(0.1748777, shape=(), dtype=float32)
# AI PCV มีความมั่นใจ 47.54%.

# %%
# VKH
test_path = ('/content/drive/My Drive/Projecteye/model1/test/VKH/DQ7866 20-01-20 LE_001_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 250ms/step
# CSC tf.Tensor(0.1748777, shape=(), dtype=float32) Normal tf.Tensor(0.1748777, shape=(), dtype=float32) PCV tf.Tensor(0.1748777, shape=(), dtype=float32) VKH tf.Tensor(0.47536686, shape=(), dtype=float32)
# AI VKH มีความมั่นใจ 47.54%.

# %% [markdown]
# ### Testing

# %%
y_test = []; y_pred = []
class_names = test_set.class_names
for images, labels in test_set:
  for i in range(len(list(labels))):
    img_array = keras.preprocessing.image.img_to_array(images[i])
    X_test = tf.expand_dims(img_array, 0)
    score = predict_model.predict(X_test)
    if score[0][0]==np.max(score):
      eye = "CSC"
    elif score[0][1]==np.max(score):
      eye = "Normal"
    elif score[0][2]==np.max(score):
      eye = "PCV"
    elif score[0][3]==np.max(score):
      eye = "VKH"
    y_pred.append(eye)
    y_test.append(class_names[labels[i]])
# Out:
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 262ms/step
# 1/1 [==============================] - 0s 261ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 251ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 256ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 249ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 293ms/step
# 1/1 [==============================] - 0s 454ms/step
# 1/1 [==============================] - 0s 425ms/step
# 1/1 [==============================] - 0s 442ms/step
# 1/1 [==============================] - 0s 422ms/step
# 1/1 [==============================] - 0s 445ms/step
# 1/1 [==============================] - 0s 413ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 257ms/step
# 1/1 [==============================] - 0s 234ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 242ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 260ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 253ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 236ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 240ms/step
# 1/1 [==============================] - 0s 243ms/step
# 1/1 [==============================] - 0s 246ms/step
# 1/1 [==============================] - 0s 250ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 281ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 255ms/step
# 1/1 [==============================] - 0s 232ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 258ms/step
# 1/1 [==============================] - 0s 239ms/step
# 1/1 [==============================] - 0s 338ms/step
# 1/1 [==============================] - 0s 434ms/step

# %%
print(y_test)
print(len(y_test))
# Out:
# ['Normal', 'CSC', 'VKH', 'CSC', 'PCV', 'CSC', 'PCV', 'VKH', 'VKH', 'VKH', 'Normal', 'CSC', 'CSC', 'Normal', 'PCV', 'Normal', 'VKH', 'VKH', 'PCV', 'Normal', 'Normal', 'VKH', 'PCV', 'PCV', 'PCV', 'Normal', 'VKH', 'CSC', 'PCV', 'CSC', 'PCV', 'VKH', 'CSC', 'CSC', 'Normal', 'PCV', 'CSC', 'CSC', 'VKH', 'Normal', 'Normal', 'PCV', 'CSC', 'CSC', 'Normal', 'Normal', 'PCV', 'VKH', 'Normal', 'CSC', 'PCV', 'VKH', 'PCV', 'VKH', 'VKH', 'Normal', 'CSC', 'PCV', 'VKH', 'Normal', 'CSC', 'VKH', 'VKH']
# 63

# %%
print(y_pred)
print(len(y_pred))
# Out:
# ['Normal', 'CSC', 'VKH', 'CSC', 'PCV', 'PCV', 'PCV', 'VKH', 'PCV', 'PCV', 'Normal', 'CSC', 'CSC', 'Normal', 'PCV', 'Normal', 'VKH', 'VKH', 'PCV', 'Normal', 'Normal', 'VKH', 'VKH', 'VKH', 'PCV', 'Normal', 'VKH', 'CSC', 'PCV', 'Normal', 'PCV', 'VKH', 'CSC', 'CSC', 'Normal', 'CSC', 'CSC', 'CSC', 'VKH', 'Normal', 'Normal', 'PCV', 'CSC', 'CSC', 'Normal', 'Normal', 'PCV', 'VKH', 'Normal', 'CSC', 'PCV', 'VKH', 'PCV', 'VKH', 'VKH', 'Normal', 'CSC', 'PCV', 'VKH', 'Normal', 'VKH', 'PCV', 'PCV']
# 63

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[13,  1,  1,  1],
#        [ 0, 15,  0,  0],
#        [ 1,  0, 12,  2],
#        [ 0,  0,  4, 13]])

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
test_set.class_names
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %%
cm_df = pd.DataFrame(cm,
                     index = ['CSC', 'Normal', 'PCV', 'VKH'], 
                     columns = ['CSC', 'Normal', 'PCV', 'VKH'])

# %%
cm_df
# Out:
#         CSC  Normal  PCV  VKH
# CSC      13       1    1    1
# Normal    0      15    0    0
# PCV       1       0   12    2
# VKH       0       0    4   13

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %% [markdown]
# ##  misclassify

# %%
# แสดง misclassify ว่ามีกี่ค่า
misclassify = 0
for i in range(len(cm)):
    for j in range(len(cm)):
        if i != j:
            misclassify += cm[i][j]
            
print('misclassification: ', misclassify)
# Out:
# misclassification:  10

# %%
# คำนวณค่า misclassification
misclassify = 1 - np.trace(cm) / np.sum(cm)

# Misclassification rate = จำนวนภาพที่ถูกจัดหมวดหมู่ผิด / จำนวนภาพทั้งหมดที่ใช้ในการทดสอบ

# แสดงผลลัพธ์ที่คิดเป็น %
print("Misclassification: {:.2f}%".format(misclassify*100))
# Out:
# Misclassification: 15.87%

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 0.841270

# %%
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('Recall: %f' % recall)
# Out:
# Recall: 0.841270

# %%
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('Precision: %f' % precision)
# Out:
# Precision: 0.846355

# %%
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.841694
