# %% [markdown]
# <a href="https://colab.research.google.com/github/Narissarach/Project_eye/blob/main/modelOCTVGG1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ModelOCT

# %%
pip install opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.19.3 in /usr/local/lib/python3.9/dist-packages (from opencv-python) (1.22.4)

# %%
import os,cv2
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import glob
import PIL
import plotly
import plotly.graph_objs as go
import pandas as pd
from numpy import array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import Sequential
from tensorflow.keras.layers import (Dense, Conv2D, AveragePooling2D, Flatten, Dropout, BatchNormalization, MaxPool2D)
import time
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from keras.utils import np_utils
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.models import model_from_json
from tensorflow.keras.models import Sequential
import requests
from IPython.display import Image
from io import BytesIO  
import pickle as p 
import plotly.graph_objs as go  
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras import backend as K
K.image_data_format()
from keras.utils import np_utils
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## เตรียมชุดของข้อมูล

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่า Mounted at /content/drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os # os จัดการเกี่ยวกับไฟล์ต่างๆ ในโฟล์เดอร์
path = '/content/drive/My Drive/Projecteye/model'  # data เราอยู่โฟล์เดอร์ไหน

# %%
batch_size = 8   # กำหนดขนาดของแต่ละการอ่านข้อมูล
img_height = 256  # ความสูงของรูปภาพแต่ละรูป
img_width = 256   # ความกว้างของรูปภาพแต่ละรูป

num_classes = 4

# %% [markdown]
# ## Train

# %%
# Train
train_dir = "/content/drive/My Drive/Projecteye/model/train"
train_datagen = ImageDataGenerator(rescale = 1./255)

train_set = train_datagen.flow_from_directory(train_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')
# Out:
# Found 502 images belonging to 4 classes.

# %%
print('Train')
ids, counts = np.unique(train_set.classes, return_counts=True)
print(ids)        # คลาส
print(counts)     # จำนวนภาพของคลาส
# Out:
# Train
# [0 1 2 3]
# [131 117 123 131]

# %%
train_set[0][0][0].shape   # W*H*3 (3 Channel RGB)
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Validation

# %%
# Validation
val_dir ="/content/drive/My Drive/Projecteye/model/validation"
val_datagen = ImageDataGenerator(rescale = 1./255)

val_set = val_datagen.flow_from_directory(val_dir, target_size=(img_height, img_width), batch_size=batch_size, class_mode='categorical')
# Out:
# Found 63 images belonging to 4 classes.

# %%
print('Validation')
ids, counts = np.unique(val_set.classes, return_counts=True)
print(ids)        # คลาส
print(counts)     # จำนวนข้อมูลของคลาส
# Out:
# Validation
# [0 1 2 3]
# [16 15 15 17]

# %% [markdown]
# ## Test

# %%
# Test
test_dir ="/content/drive/My Drive/Projecteye/model/test"
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = tf.keras.utils.image_dataset_from_directory(test_dir,image_size=(img_height, img_width))
# Out:
# Found 63 files belonging to 4 classes.

# %%
class_names = test_set.class_names
print(class_names)
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %% [markdown]
# ## Setup และโหลด Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
target_img_shape = (256,256) 
train_dir = "/content/drive/My Drive/Projecteye/model/train" #train dir
val_dir = "/content/drive/My Drive/Projecteye/model/validation" #validation dir
test_dir ="/content/drive/My Drive/Projecteye/model/test" #test dir 

#Process input แปลงข้อมูลภาพให้อยู่ในสเกลสำหรับ Model VGG16
train_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)

# อ่านไฟล์ภาพจากโฟลเดอร์ ลดสเล จัดแบ่งเป็น Batch
train_set = train_datagen.flow_from_directory(train_dir,
                                              target_size = target_img_shape, # ลดสเกลภาพ
                                              batch_size = 8,                 # แบ่งเป็น batch ละ 8 ภาพ
                                              class_mode = 'sparse')  

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
val_set = val_datagen.flow_from_directory(val_dir,
                                              target_size = target_img_shape,
                                              batch_size = 8,
                                              class_mode = 'sparse')
# Out:
# Found 502 images belonging to 4 classes.
# Found 63 images belonging to 4 classes.

# %% [markdown]
# ## Visualization

# %%
print(train_set.class_indices)
for image_batch, labels_batch in train_set:
  print(image_batch.shape)
  print(labels_batch.shape)

  img = image_batch[0] - image_batch[0].min()
  img /= 255.0
  plt.imshow(img)
  print('class:', labels_batch[0])
  break
# Out:
# {'CSC': 0, 'Normal': 1, 'PCV': 2, 'VKH': 3}
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (8, 256, 256, 3)
# (8,)
# class: 2.0

# %%
labels = (train_set.class_indices)
labels = dict((v,k) for k,v in labels.items())
labels

for i in ids:
  print('{:>8} = {}' . format(labels[i], counts[i]))
# Out:
#      CSC = 16
#   Normal = 15
#      PCV = 15
#      VKH = 17

# %%
_, train_count = np.unique(train_set.classes, return_counts=True)
_, val_count = np.unique(val_set.classes, return_counts=True)

print('สัดส่วน Validation/Training set:', val_count/train_count*100)
# Out:
# สัดส่วน Validation/Training set: [12.21374046 12.82051282 12.19512195 12.97709924]

# %% [markdown]
# ## สร้างโมเดล CNN

# %%
in_shape = (target_img_shape[0], target_img_shape[1],3)
in_shape
# Out:
# (256, 256, 3)

# %%
base_model = VGG16(include_top = False,
                      weights='imagenet',        # Load weight
                      input_shape=in_shape)

# %%
model = Sequential() # เริ่ม Model

model.add(base_model) # ตัวฐาน (Pre-trained)
model.add(Flatten())
model.add(Dense(128, activation='relu')) # ชั้นที่ 1

model.add(Dense(256, activation='relu')) # ชั้นที่ 2

model.add(Dense(4, activation='softmax')) # 4 คลาส

model.summary() # ดูสรุป
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 18,943,172
# Trainable params: 18,943,172
# Non-trainable params: 0
# _________________________________________________________________

# %%
base_model.trainable = False # Freeze ส่วนที่เป็นฐาน (ResNet50)

# %%
print("Trainable..\n---")
for variable in model.trainable_variables:
  print(variable.name)
# Out:
# Trainable..
# ---
# dense/kernel:0
# dense/bias:0
# dense_1/kernel:0
# dense_1/bias:0
# dense_2/kernel:0
# dense_2/bias:0

# %%
model.summary() # ดูสรุป
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 18,943,172
# Trainable params: 4,228,484
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# ### Compile และ Train

# %%
from keras.api._v2.keras import callbacks
import time
model.compile(loss = 'sparse_categorical_crossentropy', 
              optimizer = 'adam', 
              metrics = ['accuracy'])

start = time.time()

history = model.fit(train_set,
                    validation_data=val_set, 
                    epochs=20,verbose=1)

end = time.time()
print("Time Taken: {:.2f} minutes".format((end-start)/60))
# Out:
# Epoch 1/20
# 63/63 [==============================] - 506s 8s/step - loss: 8.0274 - accuracy: 0.5478 - val_loss: 2.1054 - val_accuracy: 0.7460
# Epoch 2/20
# 63/63 [==============================] - 504s 8s/step - loss: 0.7463 - accuracy: 0.8984 - val_loss: 2.3593 - val_accuracy: 0.7619
# Epoch 3/20
# 63/63 [==============================] - 475s 8s/step - loss: 0.4343 - accuracy: 0.9303 - val_loss: 5.4597 - val_accuracy: 0.7143
# Epoch 4/20
# 63/63 [==============================] - 506s 8s/step - loss: 0.9139 - accuracy: 0.9223 - val_loss: 2.2022 - val_accuracy: 0.8413
# Epoch 5/20
# 63/63 [==============================] - 513s 8s/step - loss: 0.7021 - accuracy: 0.9303 - val_loss: 1.7224 - val_accuracy: 0.7937
# Epoch 6/20
# 63/63 [==============================] - 492s 8s/step - loss: 0.2002 - accuracy: 0.9701 - val_loss: 2.0616 - val_accuracy: 0.8889
# Epoch 7/20
# 63/63 [==============================] - 496s 8s/step - loss: 0.2900 - accuracy: 0.9681 - val_loss: 1.2324 - val_accuracy: 0.8571
# Epoch 8/20
# 63/63 [==============================] - 493s 8s/step - loss: 0.8332 - accuracy: 0.9343 - val_loss: 2.5663 - val_accuracy: 0.8889
# Epoch 9/20
# 63/63 [==============================] - 491s 8s/step - loss: 0.4845 - accuracy: 0.9562 - val_loss: 2.4421 - val_accuracy: 0.8889
# Epoch 10/20
# 63/63 [==============================] - 492s 8s/step - loss: 0.3643 - accuracy: 0.9661 - val_loss: 3.8322 - val_accuracy: 0.9048
# Epoch 11/20
# 63/63 [==============================] - 462s 7s/step - loss: 0.3465 - accuracy: 0.9761 - val_loss: 3.7435 - val_accuracy: 0.8413
# Epoch 12/20
# 63/63 [==============================] - 490s 8s/step - loss: 0.5580 - accuracy: 0.9721 - val_loss: 3.4933 - val_accuracy: 0.8571
# Epoch 13/20
# 63/63 [==============================] - 498s 8s/step - loss: 0.0841 - accuracy: 0.9880 - val_loss: 2.6281 - val_accuracy: 0.9365
# Epoch 14/20
# 63/63 [==============================] - 493s 8s/step - loss: 0.2348 - accuracy: 0.9841 - val_loss: 2.2818 - val_accuracy: 0.9048
# Epoch 15/20
# 63/63 [==============================] - 463s 7s/step - loss: 0.4510 - accuracy: 0.9821 - val_loss: 4.9641 - val_accuracy: 0.8889
# Epoch 16/20
# 63/63 [==============================] - 494s 8s/step - loss: 0.1492 - accuracy: 0.9841 - val_loss: 2.0451 - val_accuracy: 0.9048
# Epoch 17/20
# 63/63 [==============================] - 463s 7s/step - loss: 0.0161 - accuracy: 0.9980 - val_loss: 2.3066 - val_accuracy: 0.8889
# Epoch 18/20
# 63/63 [==============================] - 496s 8s/step - loss: 6.2154e-06 - accuracy: 1.0000 - val_loss: 2.3002 - val_accuracy: 0.8889
# Epoch 19/20
# 63/63 [==============================] - 491s 8s/step - loss: 4.2821e-06 - accuracy: 1.0000 - val_loss: 2.2962 - val_accuracy: 0.8889
# Epoch 20/20
# 63/63 [==============================] - 494s 8s/step - loss: 3.3255e-06 - accuracy: 1.0000 - val_loss: 2.2905 - val_accuracy: 0.8889
# Time Taken: 168.21 minutes

# %% [markdown]
# ### Save Model

# %%
modelOCT = '/Model'
if not os.path.exists(path+modelOCT):
    os.makedirs(path+modelOCT)
os.makedirs('/content/drive/My Drive/Projecteye/savemodel/', exist_ok=True)
model.save('/content/drive/MyDrive/Projecteye/savemodel/modelOCTVGG16trans1.h5')

with open('history_model', 'wb') as file:
   p.dump(history.history, file)

filepath='modelOCTVGG16trans1.h5'
model.save(filepath)
filepath_model = 'modelOCTVGG16trans1.json'
filepath_weights = 'weightsmodelOCTVGG16trans1.h5'
model_json = model.to_json()
with open(filepath_model, "w") as json_file:
   json_file.write(model_json)

model.save_weights('weightsmodelVGG16trans1.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ### Load Model

# %%
with open('history_model', 'rb') as file:
   his = p.load(file)

h1 = go.Scatter(y=his['val_accuracy'],
mode="lines", line=dict(
width=2,
color='blue'),
name="val_accuracy"
)
h2 = go.Scatter(y=his['val_loss'],
mode="lines", line=dict(
width=2,
color='red'),
name="val_loss"
)

data = [h1,h2]
layout1 = go.Layout(title='Loss',
xaxis=dict(title='epochs'),
yaxis=dict(title=' '))
fig1 = go.Figure(data, layout=layout1)
plotly.offline.iplot(fig1, filename="testOCT")
predict_model = load_model(filepath)
predict_model.summary()
with open(filepath_model, 'r') as f:
   loaded_model_json = f.read()
predict_model = model_from_json(loaded_model_json)
predict_model.load_weights(filepath_weights)
print("Loaded model from disk")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="fdac36fe-3f1e-43d5-ba5a-dfb49fc906da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fdac36fe-3f1e-43d5-ba5a-dfb49fc906da")) {                    Plotly.newPlot(                        "fdac36fe-3f1e-43d5-ba5a-dfb49fc906da",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":"val_accuracy","y":[0.7460317611694336,0.761904776096344,0.7142857313156128,0.841269850730896,0.7936508059501648,0.8888888955116272,0.8571428656578064,0.8888888955116272,0.8888888955116272,0.9047619104385376,0.841269850730896,0.8571428656578064,0.9365079402923584,0.9047619104385376,0.8888888955116272,0.9047619104385376,0.8888888955116272,0.8888888955116272,0.8888888955116272,0.8888888955116272],"type":"scatter"},{"line":{"color":"red","width":2},"mode":"lines","name":"val_loss","y":[2.105409622192383,2.3592867851257324,5.459669589996338,2.202223777770996,1.722353458404541,2.061645984649658,1.2324097156524658,2.5662617683410645,2.4420711994171143,3.832195281982422,3.74350643157959,3.4933021068573,2.628103733062744,2.281787157058716,4.964129447937012,2.045123815536499,2.306647777557373,2.3001699447631836,2.2962424755096436,2.2905240058898926],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd378 ...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 128)               4194432
#
#  dense_1 (Dense)             (None, 256)               33024
#
#  dense_2 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 18,943,172
# Trainable params: 4,228,484
# Non-trainable params: 14,714,688
# _________________________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1924a240f542> in <cell line: 28>()
#      26    loaded_model_json = f.read()
#      27 predict_model = model_from_json(loaded_model_json)
# ---> 28 predict_model.load_weights(weightsmodelOCTVGG16trans1.h5)
#      29 print("Loaded model from disk")
#
# NameError: name 'weightsmodelOCTVGG16trans1' is not defined

# %% [markdown]
# ## ประเมิน

# %%
plt.figure(figsize = (10, 3.5))
plt.subplot(1, 2 , 1)
plt.title('Loss')
plt.plot(history.history['loss'], label = 'Train Loss')
plt.plot(history.history['val_loss'], 'r', lw = 3.2, label = 'Validation loss')
plt.legend()

# %%
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label = 'Train')
plt.plot(history.history['val_accuracy'], 'r', lw = 3.2, label = 'Validation')
plt.legend()
plt.tight_layout()
plt.show()

# %%
acc = model.evaluate(val_set, steps = len(val_set), verbose = 0)
print('score = {:.3f}' .format(acc[1]))
# Out:
# score = 0.889

# %% [markdown]
# ### Prediction

# %%
import requests
from IPython.display import Image
from io import BytesIO
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.preprocessing import image 
import keras.utils as image
from keras.models import load_model

# %%
train_set.class_indices
# Out:
# {'CSC': 0, 'Normal': 1, 'PCV': 2, 'VKH': 3}

# %%
# CSC
test_path = ('/content/drive/My Drive/Projecteye/model/test/CSC/CD7445 22-07-16 LE_001_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 1s 1s/step
# CSC tf.Tensor(0.2437189, shape=(), dtype=float32) Normal tf.Tensor(0.24584344, shape=(), dtype=float32) PCV tf.Tensor(0.26566693, shape=(), dtype=float32) VKH tf.Tensor(0.24477075, shape=(), dtype=float32)
# AI PCV มีความมั่นใจ 26.57%.

# %%
# Normal
test_path = ('/content/drive/My Drive/Projecteye/model1/test/Normal/AA0598 17-11-22 RE_000_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 1s 708ms/step
# CSC tf.Tensor(0.23500375, shape=(), dtype=float32) Normal tf.Tensor(0.24237879, shape=(), dtype=float32) PCV tf.Tensor(0.26764292, shape=(), dtype=float32) VKH tf.Tensor(0.25497448, shape=(), dtype=float32)
# AI PCV มีความมั่นใจ 26.76%.

# %%
# PCV
test_path = ('/content/drive/My Drive/Projecteye/model1/test/PCV/AF4715 18-10-17 LE_001_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 1s 733ms/step
# CSC tf.Tensor(0.22967586, shape=(), dtype=float32) Normal tf.Tensor(0.24311565, shape=(), dtype=float32) PCV tf.Tensor(0.27345636, shape=(), dtype=float32) VKH tf.Tensor(0.2537521, shape=(), dtype=float32)
# AI PCV มีความมั่นใจ 27.35%.

# %%
# VKH
test_path = ('/content/drive/My Drive/Projecteye/model1/test/VKH/DQ7866 20-01-20 LE_001_cropped.png')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("CSC",score[0],"Normal",score[1],"PCV",score[2],"VKH",score[3])
display(Image(filename=test_path,width=256, height=256))
if score[0]==np.max(score):
  eye = "CSC"
elif score[1]==np.max(score):
  eye = "Normal"
elif score[2]==np.max(score):
  eye = "PCV"
elif score[3]==np.max(score):
  eye = "VKH"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(eye, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 1s 1s/step
# CSC tf.Tensor(0.22148284, shape=(), dtype=float32) Normal tf.Tensor(0.2451108, shape=(), dtype=float32) PCV tf.Tensor(0.28609163, shape=(), dtype=float32) VKH tf.Tensor(0.24731477, shape=(), dtype=float32)
# AI PCV มีความมั่นใจ 28.61%.

# %% [markdown]
# ### Testing

# %%
y_test = []; y_pred = []
class_names = test_set.class_names
for images, labels in test_set:
  for i in range(len(list(labels))):
    img_array = keras.preprocessing.image.img_to_array(images[i])
    X_test = tf.expand_dims(img_array, 0)
    score = predict_model.predict(X_test)
    if score[0][0]==np.max(score):
      eye = "CSC"
    elif score[0][1]==np.max(score):
      eye = "Normal"
    elif score[0][2]==np.max(score):
      eye = "PCV"
    elif score[0][3]==np.max(score):
      eye = "VKH"
    y_pred.append(eye)
    y_test.append(class_names[labels[i]])
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 834ms/step
# 1/1 [==============================] - 1s 718ms/step
# 1/1 [==============================] - 1s 738ms/step
# 1/1 [==============================] - 1s 716ms/step
# 1/1 [==============================] - 1s 707ms/step
# 1/1 [==============================] - 1s 729ms/step
# 1/1 [==============================] - 1s 729ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 747ms/step
# 1/1 [==============================] - 1s 752ms/step
# 1/1 [==============================] - 1s 727ms/step
# 1/1 [==============================] - 1s 744ms/step
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 730ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 708ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 3s 3s/step
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 715ms/step
# 1/1 [==============================] - 1s 714ms/step
# 1/1 [==============================] - 1s 717ms/step
# 1/1 [==============================] - 1s 720ms/step
# 1/1 [==============================] - 1s 737ms/step
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - 1s 719ms/step
# 1/1 [==============================] - 1s 720ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 740ms/step
# 1/1 [==============================] - 1s 720ms/step
# 1/1 [==============================] - 1s 758ms/step
# 1/1 [==============================] - 1s 777ms/step
# 1/1 [==============================] - 1s 725ms/step
# 1/1 [==============================] - 1s 737ms/step
# 1/1 [==============================] - 1s 728ms/step
# 1/1 [==============================] - 1s 733ms/step
# 1/1 [==============================] - 1s 737ms/step
# 1/1 [==============================] - 1s 747ms/step
# 1/1 [==============================] - 1s 742ms/step
# 1/1 [==============================] - 1s 714ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 726ms/step
# 1/1 [==============================] - 1s 724ms/step
# 1/1 [==============================] - 1s 733ms/step

# %%
print(y_test)
print(len(y_test))
# Out:
# ['Normal', 'PCV', 'CSC', 'PCV', 'VKH', 'VKH', 'CSC', 'Normal', 'CSC', 'VKH', 'Normal', 'VKH', 'Normal', 'PCV', 'Normal', 'CSC', 'PCV', 'PCV', 'PCV', 'CSC', 'VKH', 'Normal', 'PCV', 'CSC', 'VKH', 'Normal', 'VKH', 'Normal', 'CSC', 'CSC', 'CSC', 'VKH', 'Normal', 'Normal', 'VKH', 'CSC', 'PCV', 'PCV', 'Normal', 'CSC', 'PCV', 'VKH', 'VKH', 'Normal', 'VKH', 'Normal', 'PCV', 'CSC', 'PCV', 'CSC', 'PCV', 'CSC', 'VKH', 'VKH', 'Normal', 'VKH', 'CSC', 'PCV', 'Normal', 'PCV', 'CSC', 'VKH', 'VKH']
# 63

# %%
print(y_pred)
print(len(y_pred))
# Out:
# ['PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV', 'PCV']
# 63

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 0,  0, 16,  0],
#        [ 0,  0, 15,  0],
#        [ 0,  0, 15,  0],
#        [ 0,  0, 17,  0]])

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
test_set.class_names
# Out:
# ['CSC', 'Normal', 'PCV', 'VKH']

# %%
cm_df = pd.DataFrame(cm,
                     index = ['CSC', 'Normal', 'PCV', 'VKH'], 
                     columns = ['CSC', 'Normal', 'PCV', 'VKH'])

# %%
cm_df
# Out:
#         CSC  Normal  PCV  VKH
# CSC       0       0   16    0
# Normal    0       0   15    0
# PCV       0       0   15    0
# VKH       0       0   17    0

# %%
plt.figure(figsize=(10,5))
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()

# %% [markdown]
# ##  misclassify

# %%
# แสดง misclassify ว่ามีกี่ค่า
misclassify = 0
for i in range(len(cm)):
    for j in range(len(cm)):
        if i != j:
            misclassify += cm[i][j]
            
print('misclassification: ', misclassify)
# Out:
# misclassification:  48

# %%
# คำนวณค่า misclassification
misclassify = 1 - np.trace(cm) / np.sum(cm)

# Misclassification rate = จำนวนภาพที่ถูกจัดหมวดหมู่ผิด / จำนวนภาพทั้งหมดที่ใช้ในการทดสอบ

# แสดงผลลัพธ์ที่คิดเป็น %
print("Misclassification: {:.2f}%".format(misclassify*100))
# Out:
# Misclassification: 76.19%

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score

# %%
# accuracy: (tp + tn) / (p + n)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %f' % accuracy)
# Out:
# Accuracy: 0.238095

# %%
# recall: tp / (tp + fn)
recall = recall_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('Recall: %f' % recall)
# Out:
# Recall: 0.238095

# %%
# precision tp / (tp + fp)
precision = precision_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('Precision: %f' % precision)
# Out:
# Precision: 0.056689
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
# f1: 2 tp / (2 tp + fp + fn)
f1 = f1_score(y_test, y_pred, average='weighted') ### ในส่วนของ average='weighted' หนูไม่มั่นใจว่าควรใส่เป็น macro, micro หรือ weight
print('F1 score: %f' % f1)
# Out:
# F1 score: 0.091575
