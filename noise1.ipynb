# %% [markdown]
# <a href="https://colab.research.google.com/github/Narissarach/Project_eye/blob/main/noise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่าMounted at /content/drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread("/content/drive/My Drive/testeye/testp.jpg", cv2.IMREAD_GRAYSCALE)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=567x566 at 0x7F3BA47A5310>

# %% [markdown]
# # Prewitt

# %%
kernelX = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernelY = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])

# %%
PrewittX = cv2.filter2D(img, -1, kernelX)
PrewittY = cv2.filter2D(img, -1, kernelY)

# %%
cv2_imshow(PrewittX)
# Out:
# <PIL.Image.Image image mode=L size=567x566 at 0x7F3BA5FFB1D0>

# %%
cv2_imshow(PrewittY)
# Out:
# <PIL.Image.Image image mode=L size=567x566 at 0x7F3BA5FFB410>

# %% [markdown]
# # Sobel

# %%
SobelX = cv2.Sobel(img,cv2.CV_64F,1,0)

# %%
cv2_imshow(SobelX)
# Out:
# <PIL.Image.Image image mode=L size=567x566 at 0x7F3BA6020450>

# %%
SobelY = cv2.Sobel(img,cv2.CV_64F,0,1)

# %%
cv2_imshow(SobelY)
# Out:
# <PIL.Image.Image image mode=L size=567x566 at 0x7F3BA47A6950>

# %% [markdown]
# # Canny

# %%
img_canny = cv2.Canny(img,100,200)

# %%
cv2_imshow(img_canny)
# Out:
# <PIL.Image.Image image mode=L size=567x566 at 0x7F3BA5FF7950>
