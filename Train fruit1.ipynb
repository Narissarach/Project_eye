# %% [markdown]
# <a href="https://colab.research.google.com/github/Narissarach/Project_eye/blob/main/Train%20fruit1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import PIL
import time
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import numpy as np
import pickle as p
import plotly
from tensorflow.keras.models import load_model
from tensorflow.keras.models import model_from_json
import plotly.graph_objs as go
from tensorflow import keras
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## เตรียมชุดของข้อมูล

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่า Mounted at /content/drive 
drive.mount('/content/drive')
path = '/content/drive/My Drive/fruit data'  # ชี้ว่า data เราอยู่โฟล์เดอร์ไหน
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pathlib
data_dir = pathlib.Path('/content/drive/My Drive/fruit data')

# %%
batch_size = 15   # กำหนดขนาดของแต่ละการอ่านข้อมูล
img_height = 150  # ความสูงของรูปภาพแต่ละรูป
img_width = 150   # ความกว้างของรูปภาพแต่ละรูป

# %%
image_count = len(list(data_dir.glob('*/*.png')))
print("จำนวนรูปภาพทั้งหมด = ",image_count)
# Out:
# จำนวนรูปภาพทั้งหมด =  35

# %% [markdown]
# ## Train

# %%
train = tf.keras.preprocessing.image_dataset_from_directory(data_dir,
validation_split=0.1, # s แบ่งข้อมูล เพื่อ training 90% และ validation 10%
subset="training",
seed=123,
image_size=(img_height, img_width),
batch_size=batch_size)
val = tf.keras.preprocessing.image_dataset_from_directory(
data_dir,
validation_split=0.1,
subset="validation",
seed=123,
image_size=(img_height, img_width),
batch_size=batch_size)
# Out:
# Found 35 files belonging to 5 classes.
# Using 32 files for training.
# Found 35 files belonging to 5 classes.
# Using 3 files for validation.

# %%
class_names = train.class_names
print(class_names)
# Out:
# ['apple1', 'banana1', 'mangosteen1', 'orange1', 'pineapple1']

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9,9)) #ขนาด
for images, labels in train.take(1):
  for i in range(15): #มี 15 รูป
    ax = plt.subplot(5, 5, i + 1) #แถวละ 5
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
for image_batch, labels_batch in train:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (15, 150, 150, 3)
# (15,)

# %% [markdown]
# ## Normalization

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)
normalized_ds = train.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# ## Model

# %%
num_classes = 5
epochs=20   # จำนวนครั้งที่เราจะ Train

# %%
model = Sequential([
layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
layers.Conv2D(16, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Conv2D(32, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Conv2D(64, 3, padding='same', activation='relu'),
layers.MaxPooling2D(),
layers.Flatten(),
layers.Dense(128, activation='relu'),
layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 150, 150, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 150, 150, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 75, 75, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 75, 75, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 20736)             0
#
#  dense_2 (Dense)             (None, 128)               2654336
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 2,678,565
# Trainable params: 2,678,565
# Non-trainable params: 0
# _________________________________________________________________

# %%
his = model.fit(
train,
validation_data=val,
epochs=epochs
)
# Out:
# Epoch 1/20
# 3/3 [==============================] - 1s 230ms/step - loss: 3.9027 - accuracy: 0.1562 - val_loss: 2.0143 - val_accuracy: 0.3333
# Epoch 2/20
# 3/3 [==============================] - 1s 156ms/step - loss: 1.8776 - accuracy: 0.1875 - val_loss: 1.3740 - val_accuracy: 0.3333
# Epoch 3/20
# 3/3 [==============================] - 1s 150ms/step - loss: 1.6185 - accuracy: 0.2188 - val_loss: 1.4040 - val_accuracy: 1.0000
# Epoch 4/20
# 3/3 [==============================] - 1s 160ms/step - loss: 1.5465 - accuracy: 0.4062 - val_loss: 1.5017 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 3/3 [==============================] - 1s 161ms/step - loss: 1.4296 - accuracy: 0.4375 - val_loss: 1.6202 - val_accuracy: 0.0000e+00
# Epoch 6/20
# 3/3 [==============================] - 1s 155ms/step - loss: 1.3983 - accuracy: 0.3750 - val_loss: 1.6278 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 3/3 [==============================] - 1s 157ms/step - loss: 1.3225 - accuracy: 0.4688 - val_loss: 1.1817 - val_accuracy: 0.3333
# Epoch 8/20
# 3/3 [==============================] - 1s 158ms/step - loss: 1.0664 - accuracy: 0.9375 - val_loss: 0.8838 - val_accuracy: 0.6667
# Epoch 9/20
# 3/3 [==============================] - 1s 167ms/step - loss: 1.0187 - accuracy: 0.7188 - val_loss: 0.7854 - val_accuracy: 1.0000
# Epoch 10/20
# 3/3 [==============================] - 1s 155ms/step - loss: 0.7946 - accuracy: 0.7500 - val_loss: 0.9154 - val_accuracy: 0.6667
# Epoch 11/20
# 3/3 [==============================] - 1s 157ms/step - loss: 0.7006 - accuracy: 0.7812 - val_loss: 0.7551 - val_accuracy: 0.6667
# Epoch 12/20
# 3/3 [==============================] - 1s 149ms/step - loss: 0.5267 - accuracy: 0.9375 - val_loss: 0.5166 - val_accuracy: 0.6667
# Epoch 13/20
# 3/3 [==============================] - 1s 159ms/step - loss: 0.3754 - accuracy: 0.9062 - val_loss: 0.1918 - val_accuracy: 1.0000
# Epoch 14/20
# 3/3 [==============================] - 1s 156ms/step - loss: 0.1715 - accuracy: 0.9688 - val_loss: 0.5789 - val_accuracy: 0.6667
# Epoch 15/20
# 3/3 [==============================] - 1s 154ms/step - loss: 0.1913 - accuracy: 0.9688 - val_loss: 0.1589 - val_accuracy: 1.0000
# Epoch 16/20
# 3/3 [==============================] - 1s 162ms/step - loss: 0.1752 - accuracy: 0.9688 - val_loss: 0.5383 - val_accuracy: 0.6667
# Epoch 17/20
# 3/3 [==============================] - 1s 154ms/step - loss: 0.0776 - accuracy: 1.0000 - val_loss: 0.6428 - val_accuracy: 0.6667
# Epoch 18/20
# 3/3 [==============================] - 1s 162ms/step - loss: 0.0488 - accuracy: 1.0000 - val_loss: 0.1571 - val_accuracy: 1.0000
# Epoch 19/20
# 3/3 [==============================] - 1s 158ms/step - loss: 0.0270 - accuracy: 1.0000 - val_loss: 0.1083 - val_accuracy: 1.0000
# Epoch 20/20
# 3/3 [==============================] - 1s 151ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.0500 - val_accuracy: 1.0000

# %% [markdown]
# ## Save Model

# %%
with open('history_model', 'wb') as file:
   p.dump(his.history, file)

filepath='model1.h5'
model.save(filepath)
filepath_model = 'model1.json'
filepath_weights = 'weights_model.h5'
model_json = model.to_json()
with open(filepath_model, "w") as json_file:
   json_file.write(model_json)

model.save_weights('weights_model.h5')
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# ## Load Model

# %%
with open('history_model', 'rb') as file:
   his = p.load(file)

h1 = go.Scatter(y=his['loss'],
mode="lines", line=dict(
width=2,
color='blue'),
name="loss"
)
h2 = go.Scatter(y=his['val_loss'],
mode="lines", line=dict(
width=2,
color='red'),
name="val_loss"
)

data = [h1,h2]
layout1 = go.Layout(title='Loss',
xaxis=dict(title='epochs'),
yaxis=dict(title=' '))
fig1 = go.Figure(data, layout=layout1)
plotly.offline.iplot(fig1, filename="testMNIST")
predict_model = load_model(filepath)
predict_model.summary()
with open(filepath_model, 'r') as f:
   loaded_model_json = f.read()
predict_model = model_from_json(loaded_model_json)
predict_model.load_weights(filepath_weights)
print("Loaded model from disk")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="964aa7c6-2e09-4714-9e18-2ac5de2b9475" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("964aa7c6-2e09-4714-9e18-2ac5de2b9475")) {                    Plotly.newPlot(                        "964aa7c6-2e09-4714-9e18-2ac5de2b9475",                        [{"line":{"color":"blue","width":2},"mode":"lines","name":"loss","y":[3.9027364253997803,1.8776469230651855,1.6184709072113037,1.546531081199646,1.4296488761901855,1.3983409404754639,1.3224668502807617,1.066351056098938,1.018662691116333,0.7946443557739258,0.7005762457847595,0.5266919732093811,0.37539076805114746,0.17145073413848877,0.19131648540496826,0.1751794070005417,0.07762464880943298,0.048774685710668564,0.026972204446792603,0.01746412366628647],"type":"scatter"},{"line":{"color":"red","width":2},"mode":"lines","name":"val_loss","y":[2.0142993927001953,1.3740228414535522,1.4040333032608032,1.5016673803329468,1.620231032371521,1.627766728401184,1.1816775798797607,0.8838103413581848,0.7854464054107666,0.915381908416748,0.7551479935646057,0.5165819525718689,0.19178366661071777,0.5789321064949036,0.15890483558177948,0.5382544994354248,0.642816960811615,0.1571454554796219,0.10830997675657272,0.04998527094721794],"type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 150, 150, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 150, 150, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 75, 75, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 75, 75, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 37, 37, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 18, 18, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 20736)             0
#
#  dense_2 (Dense)             (None, 128)               2654336
#
#  dense_3 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 2,678,565
# Trainable params: 2,678,565
# Non-trainable params: 0
# _________________________________________________________________
# Loaded model from disk

# %% [markdown]
# ## Prediction

# %%
import requests
from IPython.display import Image
from io import BytesIO
test_path = ('/content/drive/My Drive/a1.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple1",score[0],"banana1",score[1],"mangosteen1",score[2],"orange1",score[3],"pineapple1",score[4])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple1"
elif score[1]==np.max(score) :
   fruit = "banana1"
elif score[2]==np.max(score) :
   fruit = "mangosteen1"
elif score[3]==np.max(score) :
   fruit = "orange1"
elif score[4]==np.max(score) :
   fruit = "pineapple1"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 103ms/step
# apple1 tf.Tensor(0.9091388, shape=(), dtype=float32) banana1 tf.Tensor(4.9245226e-09, shape=(), dtype=float32) mangosteen1 tf.Tensor(0.08957305, shape=(), dtype=float32) orange1 tf.Tensor(8.332488e-06, shape=(), dtype=float32) pineapple1 tf.Tensor(0.0012798719, shape=(), dtype=float32)
# AI apple1 มีความมั่นใจ 90.91%.

# %%
test_path = ('/content/drive/My Drive/0/ap.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple1",score[0],"banana1",score[1],"mangosteen1",score[2],"orange1",score[3],"pineapple1",score[4])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple1"
elif score[1]==np.max(score) :
   fruit = "banana1"
elif score[2]==np.max(score) :
   fruit = "mangosteen1"
elif score[3]==np.max(score) :
   fruit = "orange1"
elif score[4]==np.max(score) :
   fruit = "pineapple1"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# apple1 tf.Tensor(0.99968064, shape=(), dtype=float32) banana1 tf.Tensor(8.9298696e-13, shape=(), dtype=float32) mangosteen1 tf.Tensor(0.00012758531, shape=(), dtype=float32) orange1 tf.Tensor(0.00019125044, shape=(), dtype=float32) pineapple1 tf.Tensor(4.865205e-07, shape=(), dtype=float32)
# AI apple1 มีความมั่นใจ 99.97%.

# %%
test_path = ('/content/drive/My Drive/0/ba.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple1",score[0],"banana1",score[1],"mangosteen1",score[2],"orange1",score[3],"pineapple1",score[4])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple1"
elif score[1]==np.max(score) :
   fruit = "banana1"
elif score[2]==np.max(score) :
   fruit = "mangosteen1"
elif score[3]==np.max(score) :
   fruit = "orange1"
elif score[4]==np.max(score) :
   fruit = "pineapple1"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# apple1 tf.Tensor(0.000174457, shape=(), dtype=float32) banana1 tf.Tensor(0.008382474, shape=(), dtype=float32) mangosteen1 tf.Tensor(0.009558439, shape=(), dtype=float32) orange1 tf.Tensor(0.0033263618, shape=(), dtype=float32) pineapple1 tf.Tensor(0.9785583, shape=(), dtype=float32)
# AI pineapple1 มีความมั่นใจ 97.86%.

# %%
test_path = ('/content/drive/My Drive/0/ma.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple1",score[0],"banana1",score[1],"mangosteen1",score[2],"orange1",score[3],"pineapple1",score[4])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple1"
elif score[1]==np.max(score) :
   fruit = "banana1"
elif score[2]==np.max(score) :
   fruit = "mangosteen1"
elif score[3]==np.max(score) :
   fruit = "orange1"
elif score[4]==np.max(score) :
   fruit = "pineapple1"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 19ms/step
# apple1 tf.Tensor(0.42982286, shape=(), dtype=float32) banana1 tf.Tensor(4.1706897e-08, shape=(), dtype=float32) mangosteen1 tf.Tensor(0.5546488, shape=(), dtype=float32) orange1 tf.Tensor(0.0005447416, shape=(), dtype=float32) pineapple1 tf.Tensor(0.014983531, shape=(), dtype=float32)
# AI mangosteen1 มีความมั่นใจ 55.46%.

# %%
test_path = ('/content/drive/My Drive/0/or.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple1",score[0],"banana1",score[1],"mangosteen1",score[2],"orange1",score[3],"pineapple1",score[4])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple1"
elif score[1]==np.max(score) :
   fruit = "banana1"
elif score[2]==np.max(score) :
   fruit = "mangosteen1"
elif score[3]==np.max(score) :
   fruit = "orange1"
elif score[4]==np.max(score) :
   fruit = "pineapple1"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 34ms/step
# apple1 tf.Tensor(0.5286996, shape=(), dtype=float32) banana1 tf.Tensor(7.696935e-09, shape=(), dtype=float32) mangosteen1 tf.Tensor(9.614272e-05, shape=(), dtype=float32) orange1 tf.Tensor(0.47110775, shape=(), dtype=float32) pineapple1 tf.Tensor(9.656919e-05, shape=(), dtype=float32)
# AI apple1 มีความมั่นใจ 52.87%.

# %%
test_path = ('/content/drive/My Drive/0/pi.jpg')
img = keras.preprocessing.image.load_img(
test_path, target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
predictions = predict_model.predict(img_array)
score = tf.nn.softmax(predictions[0])
print("apple1",score[0],"banana1",score[1],"mangosteen1",score[2],"orange1",score[3],"pineapple1",score[4])
display(Image(filename=test_path,width=180, height=180))
if score[0]==np.max(score) :
   fruit = "apple1"
elif score[1]==np.max(score) :
   fruit = "banana1"
elif score[2]==np.max(score) :
   fruit = "mangosteen1"
elif score[3]==np.max(score) :
   fruit = "orange1"
elif score[4]==np.max(score) :
   fruit = "pineapple1"
print(
"AI {} มีความมั่นใจ {:.2f}%."
.format(fruit, 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# apple1 tf.Tensor(0.5010684, shape=(), dtype=float32) banana1 tf.Tensor(5.4026657e-07, shape=(), dtype=float32) mangosteen1 tf.Tensor(0.06011645, shape=(), dtype=float32) orange1 tf.Tensor(0.015344281, shape=(), dtype=float32) pineapple1 tf.Tensor(0.42347035, shape=(), dtype=float32)
# AI apple1 มีความมั่นใจ 50.11%.
