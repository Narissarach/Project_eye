# %% [markdown]
# <a href="https://colab.research.google.com/github/Narissarach/Project_eye/blob/main/crop%20normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import cv2
import matplotlib.pyplot as plt
import pathlib
import numpy as np 
import sys

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่าMounted at /content/drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os # os จัดการเกี่ยวกับไฟล์ต่างๆ ในโฟล์เดอร์

# %%
path = '/content/drive/My Drive/2022Project/data/train Normal'  # ชี้ว่า data เราอยู่โฟล์เดอร์ไหน

# %%
data_dir = pathlib.Path('/content/drive/My Drive/2022Project/data/train Normal')

# %%
dir_forsave = os.chdir('/content/drive/My Drive/2022Project/Project/Train/Normal') # สร้าง folder ใหม่ ชื่อ cropped

# %%
from PIL import Image

filepath = "/content/drive/My Drive/2022Project/data/train Normal"

# Loop through all provided arguments
for filename in os.listdir(filepath):
    if "." not in filename:
        continue
    ending = filename.split(".")[1]
    if ending not in "png":
        continue

    try:
        # Attempt to open an image file
        image = Image.open(os.path.join(filepath, filename))
    except IOError as e:
        # Report error, and then skip to the next argument
        print ,"Problem opening", filepath, ":", e
        continue

    # Perform operations on the image here
    cropped = image.crop((496, 0, 1200, 400))

    # Split our origional filename into name and extension 
    name, extension = os.path.splitext(filename)

    print(name + '_cropped.png')
    cropped.save(os.path.join("/content/drive/My Drive/2022Project/Project/Train/Normal", name + '_cropped.png'))
# Out:
# KI5256 17-09-21 RE_002008_cropped.png
# KI5256 17-09-21 RE_002010_cropped.png
# KI5256 17-09-21 RE_002007_cropped.png
# KI5256 17-09-21 RE_002009_cropped.png
# KI5256 17-09-21 RE_002014_cropped.png
# KI5256 17-09-21 RE_002013_cropped.png
# KI5256 17-09-21 RE_002011_cropped.png
# KI5256 17-09-21 RE_002015_cropped.png
# KI5256 17-09-21 RE_002012_cropped.png
# KI5256 17-09-21 RE_002020_cropped.png
# KI5256 17-09-21 RE_002019_cropped.png
# KI5256 17-09-21 RE_002018_cropped.png
# KI5256 17-09-21 RE_002016_cropped.png
# KI5256 17-09-21 RE_002017_cropped.png
# KI5256 17-09-21 RE_002022_cropped.png
# KI5256 17-09-21 RE_002024_cropped.png
# KI5256 17-09-21 RE_002021_cropped.png
# KI5256 17-09-21 RE_002023_cropped.png
# IV2554 26-02-20 RE_001000_cropped.png
# IV2554 26-02-20 RE_001002_cropped.png
# IV2554 26-02-20 RE_000_cropped.png
# IV2554 26-02-20 RE_001001_cropped.png
# IV2554 26-02-20 RE_001003_cropped.png
# IV2554 26-02-20 RE_001006_cropped.png
# IV2554 26-02-20 RE_001005_cropped.png
# ...

# %%
[len(os.listdir(dir_forsave))

,len(os.listdir(data_dir))]
# Out:
# [4469, 4469]
